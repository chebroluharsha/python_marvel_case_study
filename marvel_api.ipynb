# %%
#ACTIVITY_5
import argparse
from asyncio.windows_events import NULL
parser = argparse.ArgumentParser(description='Activity')
parser.add_argument("-apikey", "--api_key", help="adds api_key", default= NULL)
parser.add_argument("-hash", "--hash", help="adds hash", default= NULL)
args, unknown = parser.parse_known_args()   #add CLI arguements while executing in CLI

print("API KEY",args.api_key)
print("HASH",args.hash)
api_key = args.api_key
hash = args.hash 
# api_key="97b5663a002e278716486c5066199100"
# hash="a6e47f7f74987d6bfcb7e67c85e8e85e"
#we got hashkey by keeping timestamp(2)_privatekey_publickey

# %%
#ACTIVITY_2
# !sudo pip3 install requests
# from IPython import get_ipython
from pprint import pprint as pp
import requests     #use request lib to call REST api
import json 
import pandas as pd

url_ad="http://gateway.marvel.com/v1/public/characters"   #url
  
df_final = pd.DataFrame()
flag = 0
for offs in range(0,1700,100):
    parameters={"apikey":api_key,"hash":hash,"ts":"2","limit":"100","offset":offs} #define all the parameters and keys
    response=requests.get(url=url_ad,params=parameters) #we are using url alongwith api key(public) as well as hash key and also by inducing the parameters nameStartswith and limit
    res=response.json()
    # pp(response.json()) 
    df = pd.DataFrame.from_dict(res['data']['results'], orient='columns')  #converting into dataframe and then extracting it from the nested dictionary results
    # print(df.shape)
    if flag == 0:
        df_final = df
        flag = 1
    else:
        df_final = pd.concat([df_final,df],join = 'outer')

# df_final.info()
print("-----ACTIVITY: 2-----")
print("Total_df_shape",df_final.shape) 
print("Result:",df_final)
# Out:
# (1562, 11)

# %%
#ACTIVITY_3
#Function for making the api call 
def ch_gen(nameStartsWith,  hash=NULL, API_key= NULL):   #giving default value as null helps us in giving a clearer error message to the user
    if (API_key == NULL or hash == NULL):
        raise Exception("API_key or hash cannot be NULL") 

    url_ad="http://gateway.marvel.com/v1/public/characters"   #url
  
    df_final = pd.DataFrame()
    flag = 0
    for offs in range(0,1700,100):
        parameters={"apikey":api_key,"hash":hash,"ts":"2","limit":"100","offset":offs} #define all the parameters and keys
        response=requests.get(url=url_ad,params=parameters) #we are using url alongwith api key(public) as well as hash key and also by inducing the parameters nameStartswith and limit
        res=response.json()
        # pp(response.json()) 
        df = pd.DataFrame.from_dict(res['data']['results'], orient='columns')  #converting into dataframe and then extracting it from the nested dictionary results
        # print(df.shape)
        if flag == 0:
            df_final = df
            flag = 1
        else:
            df_final = pd.concat([df_final,df],join = 'outer')

    return df_final


result=ch_gen('B', hash=hash,API_key=api_key)    #Function call
print("-----ACTIVITY: 3-----")
print("RESULT:",result)   #WE are giving values for api and hash and storing the fucnction as result
# Out:
#          id                        name  \
# 0   1011334                     3-D Man
# 1   1017100                A-Bomb (HAS)
# 2   1009144                      A.I.M.
# 3   1010699                 Aaron Stack
# 4   1009146  Abomination (Emil Blonsky)
# ..      ...                         ...
# 57  1011515                        Zeus
# 58  1011127                      Zodiak
# 59  1009741        Zombie (Simon Garth)
# 60  1011183                       Zuras
# 61  1009742                       Zzzax
#
#                                           description  \
# 0
# 1   Rick Jones has been Hulk's best bud since day ...
# 2   AIM is a terrorist organization bent on destro...
# 3
# 4   Formerly known as Emil Blonsky, a spy of Sovie...
# ..                                                ...
# 57  Zeus ruled a peaceful Olympus for centuries wh...
# 58  Twelve demons merged with Norman Harrison, who...
# 59  War hero Simon Garth was turned into a zombie ...
# 60         Zuras was once the leader of the Eternals.
# 61  A chain reaction in an atomic reactor, a resul...
#
#                     modified  \
# 0   2014-04-29T14:18:17-0400
# 1   2013-09-18T15:54:04-0400
# 2   2013-10-17T14:41:30-0400
# 3   1969-12-31T19:00:00-0500
# 4   2012-03-20T12:32:12-0400
# ..                       ...
# 57  2021-08-18T22:06:56-0400
# 58  1969-12-31T19:00:00-0500
# 59  1969-12-31T19:00:00-0500
# 60  1969-12-31T19:00:00-0500
# 61  2013-12-17T18:35:54-0500
#
#                                             thumbnail  \
# 0   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 1   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 2   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 3   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 4   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# ..                                                ...
# 57  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 58  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 59  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 60  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 61  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
#
#                                           resourceURI  \
# 0   http://gateway.marvel.com/v1/public/characters...
# 1   http://gateway.marvel.com/v1/public/characters...
# 2   http://gateway.marvel.com/v1/public/characters...
# 3   http://gateway.marvel.com/v1/public/characters...
# 4   http://gateway.marvel.com/v1/public/characters...
# ..                                                ...
# 57  http://gateway.marvel.com/v1/public/characters...
# 58  http://gateway.marvel.com/v1/public/characters...
# 59  http://gateway.marvel.com/v1/public/characters...
# 60  http://gateway.marvel.com/v1/public/characters...
# 61  http://gateway.marvel.com/v1/public/characters...
#
#                                                comics  \
# 0   {'available': 12, 'collectionURI': 'http://gat...
# 1   {'available': 4, 'collectionURI': 'http://gate...
# 2   {'available': 52, 'collectionURI': 'http://gat...
# 3   {'available': 14, 'collectionURI': 'http://gat...
# 4   {'available': 54, 'collectionURI': 'http://gat...
# ..                                                ...
# 57  {'available': 36, 'collectionURI': 'http://gat...
# 58  {'available': 1, 'collectionURI': 'http://gate...
# 59  {'available': 1, 'collectionURI': 'http://gate...
# 60  {'available': 3, 'collectionURI': 'http://gate...
# 61  {'available': 5, 'collectionURI': 'http://gate...
#
#                                                series  \
# 0   {'available': 3, 'collectionURI': 'http://gate...
# 1   {'available': 2, 'collectionURI': 'http://gate...
# 2   {'available': 34, 'collectionURI': 'http://gat...
# 3   {'available': 3, 'collectionURI': 'http://gate...
# 4   {'available': 27, 'collectionURI': 'http://gat...
# ..                                                ...
# 57  {'available': 13, 'collectionURI': 'http://gat...
# 58  {'available': 1, 'collectionURI': 'http://gate...
# 59  {'available': 1, 'collectionURI': 'http://gate...
# 60  {'available': 3, 'collectionURI': 'http://gate...
# 61  {'available': 4, 'collectionURI': 'http://gate...
#
#                                               stories  \
# 0   {'available': 21, 'collectionURI': 'http://gat...
# 1   {'available': 7, 'collectionURI': 'http://gate...
# 2   {'available': 54, 'collectionURI': 'http://gat...
# 3   {'available': 27, 'collectionURI': 'http://gat...
# 4   {'available': 64, 'collectionURI': 'http://gat...
# ..                                                ...
# 57  {'available': 43, 'collectionURI': 'http://gat...
# 58  {'available': 1, 'collectionURI': 'http://gate...
# 59  {'available': 1, 'collectionURI': 'http://gate...
# 60  {'available': 3, 'collectionURI': 'http://gate...
# 61  {'available': 6, 'collectionURI': 'http://gate...
#
#                                                events  \
# 0   {'available': 1, 'collectionURI': 'http://gate...
# 1   {'available': 0, 'collectionURI': 'http://gate...
# 2   {'available': 0, 'collectionURI': 'http://gate...
# 3   {'available': 0, 'collectionURI': 'http://gate...
# 4   {'available': 1, 'collectionURI': 'http://gate...
# ..                                                ...
# 57  {'available': 0, 'collectionURI': 'http://gate...
# 58  {'available': 0, 'collectionURI': 'http://gate...
# 59  {'available': 0, 'collectionURI': 'http://gate...
# 60  {'available': 0, 'collectionURI': 'http://gate...
# 61  {'available': 0, 'collectionURI': 'http://gate...
#
#                                                  urls
# 0   [{'type': 'detail', 'url': 'http://marvel.com/...
# 1   [{'type': 'detail', 'url': 'http://marvel.com/...
# 2   [{'type': 'detail', 'url': 'http://marvel.com/...
# 3   [{'type': 'detail', 'url': 'http://marvel.com/...
# 4   [{'type': 'detail', 'url': 'http://marvel.com/...
# ..                                                ...
# 57  [{'type': 'detail', 'url': 'http://marvel.com/...
# 58  [{'type': 'detail', 'url': 'http://marvel.com/...
# 59  [{'type': 'detail', 'url': 'http://marvel.com/...
# 60  [{'type': 'detail', 'url': 'http://marvel.com/...
# 61  [{'type': 'detail', 'url': 'http://marvel.com/...
#
# [1562 rows x 11 columns]

# %%
#ACTIVITY_4
def ch_filter(df1,col,filter_condition):
    return df1.query(col+filter_condition)   #optimal method for the above code.

# def ch_filter1(df1,col,filter_condition):
#     total_condition = col+filter_condition;
#     res = (df1.query(total_condition));  #code to define and convert to df for a filter conditionbased on selected column and the condition on that column
#     return res 

result2= ch_filter(df1=result, col='name',filter_condition='.str.startswith("A")')
print("-----ACTIVITY: 4-----")
print("Result: Characters Starting with 'A'",result2)
# Out:
#          id                        name  \
# 1   1017100                A-Bomb (HAS)
# 2   1009144                      A.I.M.
# 3   1010699                 Aaron Stack
# 4   1009146  Abomination (Emil Blonsky)
# 5   1016823      Abomination (Ultimate)
# ..      ...                         ...
# 80  1009163                      Aurora
# 81  1009164                   Avalanche
# 82  1009165                    Avengers
# 83  1015239         Avengers (Ultimate)
# 84  1011766             Azazel (Mutant)
#
#                                           description  \
# 1   Rick Jones has been Hulk's best bud since day ...
# 2   AIM is a terrorist organization bent on destro...
# 3
# 4   Formerly known as Emil Blonsky, a spy of Sovie...
# 5
# ..                                                ...
# 80
# 81
# 82  Earth's Mightiest Heroes joined forces to take...
# 83
# 84  A mutant from biblical times, Azazel is the ru...
#
#                     modified  \
# 1   2013-09-18T15:54:04-0400
# 2   2013-10-17T14:41:30-0400
# 3   1969-12-31T19:00:00-0500
# 4   2012-03-20T12:32:12-0400
# 5   2012-07-10T19:11:52-0400
# ..                       ...
# 80  2011-05-10T15:56:51-0400
# 81  2010-11-05T14:30:34-0400
# 82  2020-07-21T10:29:09-0400
# 83  2012-07-10T19:18:28-0400
# 84  2011-06-09T11:04:52-0400
#
#                                             thumbnail  \
# 1   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 2   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 3   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 4   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 5   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# ..                                                ...
# 80  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 81  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 82  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 83  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 84  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
#
#                                           resourceURI  \
# 1   http://gateway.marvel.com/v1/public/characters...
# 2   http://gateway.marvel.com/v1/public/characters...
# 3   http://gateway.marvel.com/v1/public/characters...
# 4   http://gateway.marvel.com/v1/public/characters...
# 5   http://gateway.marvel.com/v1/public/characters...
# ..                                                ...
# 80  http://gateway.marvel.com/v1/public/characters...
# 81  http://gateway.marvel.com/v1/public/characters...
# 82  http://gateway.marvel.com/v1/public/characters...
# 83  http://gateway.marvel.com/v1/public/characters...
# 84  http://gateway.marvel.com/v1/public/characters...
#
#                                                comics  \
# 1   {'available': 4, 'collectionURI': 'http://gate...
# 2   {'available': 52, 'collectionURI': 'http://gat...
# 3   {'available': 14, 'collectionURI': 'http://gat...
# 4   {'available': 54, 'collectionURI': 'http://gat...
# 5   {'available': 2, 'collectionURI': 'http://gate...
# ..                                                ...
# 80  {'available': 82, 'collectionURI': 'http://gat...
# 81  {'available': 41, 'collectionURI': 'http://gat...
# 82  {'available': 2017, 'collectionURI': 'http://g...
# 83  {'available': 39, 'collectionURI': 'http://gat...
# 84  {'available': 3, 'collectionURI': 'http://gate...
#
#                                                series  \
# 1   {'available': 2, 'collectionURI': 'http://gate...
# 2   {'available': 34, 'collectionURI': 'http://gat...
# 3   {'available': 3, 'collectionURI': 'http://gate...
# 4   {'available': 27, 'collectionURI': 'http://gat...
# 5   {'available': 2, 'collectionURI': 'http://gate...
# ..                                                ...
# 80  {'available': 18, 'collectionURI': 'http://gat...
# 81  {'available': 18, 'collectionURI': 'http://gat...
# 82  {'available': 621, 'collectionURI': 'http://ga...
# 83  {'available': 11, 'collectionURI': 'http://gat...
# 84  {'available': 3, 'collectionURI': 'http://gate...
#
#                                               stories  \
# 1   {'available': 7, 'collectionURI': 'http://gate...
# 2   {'available': 54, 'collectionURI': 'http://gat...
# 3   {'available': 27, 'collectionURI': 'http://gat...
# 4   {'available': 64, 'collectionURI': 'http://gat...
# 5   {'available': 3, 'collectionURI': 'http://gate...
# ..                                                ...
# 80  {'available': 94, 'collectionURI': 'http://gat...
# 81  {'available': 48, 'collectionURI': 'http://gat...
# 82  {'available': 2843, 'collectionURI': 'http://g...
# 83  {'available': 33, 'collectionURI': 'http://gat...
# 84  {'available': 4, 'collectionURI': 'http://gate...
#
#                                                events  \
# 1   {'available': 0, 'collectionURI': 'http://gate...
# 2   {'available': 0, 'collectionURI': 'http://gate...
# 3   {'available': 0, 'collectionURI': 'http://gate...
# 4   {'available': 1, 'collectionURI': 'http://gate...
# 5   {'available': 0, 'collectionURI': 'http://gate...
# ..                                                ...
# 80  {'available': 4, 'collectionURI': 'http://gate...
# 81  {'available': 7, 'collectionURI': 'http://gate...
# 82  {'available': 33, 'collectionURI': 'http://gat...
# 83  {'available': 0, 'collectionURI': 'http://gate...
# 84  {'available': 0, 'collectionURI': 'http://gate...
#
#                                                  urls
# 1   [{'type': 'detail', 'url': 'http://marvel.com/...
# 2   [{'type': 'detail', 'url': 'http://marvel.com/...
# 3   [{'type': 'detail', 'url': 'http://marvel.com/...
# 4   [{'type': 'detail', 'url': 'http://marvel.com/...
# 5   [{'type': 'detail', 'url': 'http://marvel.com/...
# ..                                                ...
# 80  [{'type': 'detail', 'url': 'http://marvel.com/...
# 81  [{'type': 'detail', 'url': 'http://marvel.com/...
# 82  [{'type': 'detail', 'url': 'http://marvel.com/...
# 83  [{'type': 'detail', 'url': 'http://marvel.com/...
# 84  [{'type': 'detail', 'url': 'http://marvel.com/...
#
# [84 rows x 11 columns]
